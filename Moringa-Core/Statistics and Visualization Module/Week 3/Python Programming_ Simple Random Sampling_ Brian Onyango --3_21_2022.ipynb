# %% [markdown]
# <font color="green">To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.</font>

# %% [markdown]
# # Python Programming:  Simple Random Sampling

# %% [markdown]
# ## Importing our Libraries

# %%
# importing numpy
import numpy as np

# importing pandas
import pandas as pd

# importing random module
# we will use random.sample() function to return a k length 
# list of unique elements chosen from our population
import random

# %% [markdown]
# ## 1.0 Selecting More than One item from a List

# %%
# Example 1
# ---
# Selecting more than one item from a list 

list = [20, 40, 80, 100, 120]
print ("Choosing 3 random items from a list using sample function", random.sample(list, k=3))

list = [20, 40, 20, 20, 20]
print ("Choosing 3 random items from a list using sample function",random.sample(list, k=3))

# As you can see we pass k=3 to choose 3 random elements from a list. 
# In return, we got a list of 3 random items.
# Out:
# Choosing 3 random items from a list using sample function [120, 100, 20]
# Choosing 3 random items from a list using sample function [20, 40, 20]

# %% [markdown]
# ### <font color="green"> 1.0 Challenges</font>

# %%
# Challenge 1
# ---
# Question: Create a list containing 10 counties in Kenya 
# then select 2 random counties from the list.
listn = ['nakuru', 'nairobi', 'kisumu', 'mombasa','narok','makueni','kitui','machakos','kilifi','kwale']
print ("Choosing 3 random items from a list using sample function", random.sample(listn, k=3))
# Out:
# Choosing 3 random items from a list using sample function ['machakos', 'kisumu', 'mombasa']

# %% [markdown]
# ## 2.0  Selecting the Random Sample from Dictionary

# %%
# Example 1
# ---
# We can select a random key-value pair from the dictionary as shown 
# ---
#
marks_dict = {
  "Kelly": 55,
  "jhon": 70,
  "Donald": 60,
  "Lennin" :50
}

print ("Choosing 2 random items from a dictionary using sample method ", random.sample(marks_dict.items(), k=2))
# Out:
# Choosing 2 random items from a dictionary using sample method  [('jhon', 70), ('Lennin', 50)]

# %% [markdown]
# ### <font color="green">2.0 Challenges</font>

# %%
# Challenge 1
# ---
# A caterer offers three different food packages; 
# bronze package: starch:rice stew:chicken curry vegetable:cabbages desert:melon
# silver package: starch:rice and chappati  stew:beef curry vegetable:spinach desert:melon and bananas
# gold package: starch:rice, chappati and mukimo stew: beef curry vegetable:spinach and managu desert: tart
# Create a dictionary that stores the above information and select a sample of size 2 
# ---
package_dict = {
  "bronze package": 'starch:rice stew:chicken curry vegetable:cabbages desert:melon',
  "silver package": 'starch:rice and chappati  stew:beef curry vegetable:spinach desert:melon and bananas',
  "gold package": 'starch:rice, chappati and mukimo stew: beef curry vegetable:spinach and managu desert: tart',
}
print ("Choosing 2 random items from a dictionary using sample method ", random.sample(package_dict.items(), k=2))
# Out:
# Choosing 2 random items from a dictionary using sample method  [('gold package', 'starch:rice, chappati and mukimo stew: beef curry vegetable:spinach and managu desert: tart'), ('silver package', 'starch:rice and chappati  stew:beef curry vegetable:spinach desert:melon and bananas')]

# %% [markdown]
# ## 3.0 Selecting a Random Sample with Replacement to including repetition

# %%
# Example 1
# ---
# We can select a random sample with replacement to include repetition as shown below
# ---
# 
names = ["Roger", "Nadal", "Novac", "Andre", "Sarena", "Mariya", "Martina"]

print("random sample with replacement to including repetition ", random.choices(names, k=3))
# Out:
# random sample with replacement to including repetition  ['Sarena', 'Andre', 'Sarena']

# %% [markdown]
# ### <font color="green">3.0 Challenges</font>

# %%
# Challenge 1
# ---
# Question: Select a random sample of 3 with replacement to include replacement from the 
# following list of months
# ---
#

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
          'August', 'September', 'October', 'November', 'December']

print("random sample with replacement to including repetition ", random.choices(months, k=3))
# Out:
# random sample with replacement to including repetition  ['June', 'March', 'July']

# %% [markdown]
# ## 4.0 Selecting a Random Sample from a Range of Integers

# %%
# Example 1
# ---
# We can select a random sample from a range of integers as shown below
# ---
# 

weight_set = {40, 50, 55, 65, 75, 80}

print ("Choosing 4 random items from a set ", random.sample(weight_set, k=4))
# Out:
# Choosing 4 random items from a set  [50, 75, 55, 80]

# %% [markdown]
# ### <font color="green">4.1 Challenges</font>

# %%
# Challenge 1
# ---
# Question: Select a random sample from a range of integers as shown below
# --- 
# 
weight_set = {4, 5, 6, 7, 8, 9, 10}

print ("Choosing 4 random items from a set ", random.sample(weight_set, k=4))
# Out:
# Choosing 4 random items from a set  [4, 7, 9, 8]

# %% [markdown]
# ## 5.0 Selecting a Sample Array from a Large multidimensional Array

# %%
# Example 1
# ---
# We can select a sample array from a large multidimensional array as shown
# ---
# 

array = np.array([[2 ,4, 6], [5, 10, 15], [6, 12, 18], [7, 14, 21], [8, 16, 24]]) 
print("Printing 2D Array")
print(array)

# selecting multiple random rows from the 2D as shown
print("Selecting multiple random rows from the 2D array")
randomRows = np.random.randint(5, size=2)
for i in randomRows:
  print(array[i,:])
# Out:
# Printing 2D Array
# [[ 2  4  6]
#  [ 5 10 15]
#  [ 6 12 18]
#  [ 7 14 21]
#  [ 8 16 24]]
# Selecting multiple random rows from the 2D array
# [ 6 12 18]
# [ 7 14 21]

# %% [markdown]
# ### <font color="green">5.0 Challenges</font>

# %%
# Challenge 1
# ---
# Question: Select two arrays from the given multidimensional array
# ---
# 

a = [[2, 4, 6, 8, 10], [3, 6, 9, 12, 15], [4, 8, 12, 16, 20], [1 ,2 , 4, 5, 6], [5, 10, 15, 20, 25], [6, 12, 18, 24, 30], [7, 14, 21, 28, 35]]  
array = np.array(a) 
print("Printing 2D Array")
print(array)

# selecting multiple random rows from the 2D as shown
print("Selecting multiple random rows from the 2D array")
randomRows = np.random.randint(5, size=2)
for i in randomRows:
  print(array[i,:])
# Out:
# Printing 2D Array
# [[ 2  4  6  8 10]
#  [ 3  6  9 12 15]
#  [ 4  8 12 16 20]
#  [ 1  2  4  5  6]
#  [ 5 10 15 20 25]
#  [ 6 12 18 24 30]
#  [ 7 14 21 28 35]]
# Selecting multiple random rows from the 2D array
# [ 2  4  6  8 10]
# [ 4  8 12 16 20]

# %% [markdown]
# ## 6.0 Selecting Random Samples from a Dataset

# %%
# Example 1
# ---
# Selecting a random sample from the following medical appointments dataset
# ---
# Dataset url = http://bit.ly/MedicalAppointmentsDataset
# ---
# 

# Loading the dataset
medical_df = pd.read_csv("http://bit.ly/MedicalAppointmentsDataset")

# Determining the size
print(medical_df.shape)


# Previewing the dataset
print(medical_df.head())

# Selecting the sample 
medical_sample = medical_df.sample(n = 10, replace="False")
print(medical_sample)
# Out:
# (110527, 14)
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 91581   7.124323e+14        5758548      M  2016-06-01T10:53:26Z
# 20935   1.622654e+14        5644982      F  2016-05-02T09:21:39Z
# 76632   8.694464e+13        5742800      F  2016-05-30T08:23:22Z
# 105701  2.833933e+13        5773724      F  2016-06-06T07:28:51Z
# 93761   2.591167e+12        5728608      M  2016-05-20T16:59:54Z
# 75031   3.559475e+13        5644796      F  2016-05-02T09:07:31Z
# 9775    2.559988e+12        5661063      F  2016-05-05T07:10:27Z
# 102150  3.651977e+13        5755470      F  2016-06-01T07:24:11Z
# 66760   2.714365e+14        5666586      M  2016-05-05T18:15:53Z
# 74340   2.863523e+14        5670770      F  2016-05-06T14:38:27Z
#
#               AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 91581   2016-06-01T00:00:00Z   27        GURIGICA            0             0
# 20935   2016-05-04T00:00:00Z   15  NOVA PALESTINA            0             0
# 76632   2016-05-30T00:00:00Z   32      ANDORINHAS            1             0
# 105701  2016-06-06T00:00:00Z   84          CENTRO            0             0
# 93761   2016-06-06T00:00:00Z    1     MARIA ORTIZ            0             0
# 75031   2016-05-17T00:00:00Z   56       SÃO PEDRO            0             0
# 9775    2016-05-09T00:00:00Z   71           ROMÃO            1             0
# 102150  2016-06-01T00:00:00Z    2        REDENÇÃO            0             0
# 66760   2016-05-05T00:00:00Z   59  JARDIM CAMBURI            0             0
# 74340   2016-05-10T00:00:00Z   63  JARDIM CAMBURI            0             1
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# 91581          0           0        0             0      No
# 20935          0           0        0             0     Yes
# 76632          0           0        0             0      No
# 105701         0           0        0             0      No
# 93761          0           0        0             1      No
# 75031          0           0        0             0      No
# 9775           0           0        0             0      No
# 102150         0           0        0             0      No
# 66760          0           0        0             0      No
# 74340          1           0        0             1      No

# %% [markdown]
# ### <font color="green">6.0 Challenges </font>

# %%
# Challenge 1
# ---
# Select a random sample of 10 from the given dataset below 
# ---
# Dataset url = http://bit.ly/DSRussianInvestigation
# ---
#
# Loading the dataset
df = pd.read_csv("http://bit.ly/DSRussianInvestigation")

# Determining the size
print(df.shape)


# Previewing the dataset
print(df.head())

# Selecting the sample 
df_sample = df.sample(n = 10, replace="False")
print(df_sample)
# Out:
# (194, 13)
#   investigation investigation-start investigation-end  investigation-days  \
# 0     watergate          1973-05-19        1977-06-19                1492
# 1     watergate          1973-05-19        1977-06-19                1492
# 2     watergate          1973-05-19        1977-06-19                1492
# 3     watergate          1973-05-19        1977-06-19                1492
# 4     watergate          1973-05-19        1977-06-19                1492
#
#                   name  indictment-days          type     cp-date  cp-days  \
# 0      James W. McCord            -246.0   conviction  1973-01-30   -109.0
# 1    Bernard L. Barker            -246.0   conviction  1973-01-15   -124.0
# 2    Bernard L. Barker             292.0   conviction  1974-07-12    419.0
# 3  Eugenio R. Martinez            -246.0  guilty-plea  1973-01-15   -124.0
# 4  Eugenio R. Martinez             292.0   conviction  1974-07-12    419.0
#
#    overturned  pardoned  american      president
# 0       False     False      True  Richard Nixon
# 1       False     False      True  Richard Nixon
# 2        True     False      True  Richard Nixon
# 3       False      True      True  Richard Nixon
# 4        True     False      True  Richard Nixon
#     investigation investigation-start investigation-end  investigation-days  \
# 179        russia          2017-05-17               NaN                 659
# 133    whitewater          1994-08-05        2002-03-06                2770
# 166        russia          2017-05-17               NaN                 659
# 131    whitewater          1994-08-05        2002-03-06                2770
# 193        russia          2017-05-17               NaN                 659
# 166        russia          2017-05-17               NaN                 659
# 128    whitewater          1994-08-05        2002-03-06                2770
# 89    iran-contra          1986-12-19        1993-08-03                2419
# 22      watergate          1973-05-19        1977-06-19                1492
# 157        herman          1998-05-26        2000-04-07                 682
#
#                     name  indictment-days          type     cp-date  cp-days  \
# 179  Konstantin Kilimnik             387.0   indictment         NaN      NaN
# 133      Charles C. Owen            1364.0   indictment         NaN      NaN
# 166   Russian national 3             275.0   indictment         NaN      NaN
# 131      Suzanna Hubbell            1364.0   indictment         NaN      NaN
# 193          Roger Stone             618.0   indictment         NaN      NaN
# 166   Russian national 3             275.0   indictment         NaN      NaN
# 128       Susan McDougal             377.0   conviction  1996-05-26    660.0
# 89       Clair E. George            1722.0   conviction  1992-12-10   2183.0
# 22       Russell DeYoung             151.0  guilty-plea  1973-10-17    151.0
# 157         Abdul Rahman             631.0   indictment         NaN      NaN
#
#      overturned  pardoned  american      president
# 179       False     False     False   Donald Trump
# 133       False     False      True   Bill Clinton
# 166       False     False     False   Donald Trump
# 131       False     False      True   Bill Clinton
# 193       False     False      True   Donald Trump
# 166       False     False     False   Donald Trump
# 128       False      True      True   Bill Clinton
# 89        False      True      True  Ronald Reagan
# 22        False     False      True  Richard Nixon
# 157       False     False     False   Bill Clinton

# %%
# Challenge 2
# ---
# A medical company would like to follow up with 50 patients who never showed up for appointments 
# but received an sms. Select a random sample from such patients given the medical dataset below 
# ---
# Dataset 
url = "http://bit.ly/MedicalAppointmentsDataset"
df = pd.read_csv(url)
print(df.shape)

#Filter the patients who received the sms
df = df[df['SMS_received'] ==1]

# Selecting the sample 
df_sample = df.sample(n = 50, replace="False")
print(df_sample)
# Out:
# (110527, 14)
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 5732    1.335689e+10        5731923      F  2016-05-24T10:43:21Z
