# %% [markdown]
# # Exploratory Data Analysis: Univariate Analysis

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Question

# %% [markdown]
# > How can a US insurance company determine the top 10 cities where its clients have the highest annual income for persons aged 40 and below?

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# ## 2. Reading the Data

# %%
# Loading the Data from the source i.e. csv
# Dataset 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = "http://bit.ly/MedicalCitiesIncomeDataset"
df = pd.read_csv(url)

# %% [markdown]
# ## 3. Checking the Data

# %%
# Determining the no. of records in our dataset
df.shape
# Out:
# (150000, 6)

# %%
# Previewing the top of our dataset
df.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
# Previewing the bottom of our dataset
df.tail()
# Out:
#         Number    City  Gender  Age    Income Illness
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No

# %%
# Checking whether each column has an appropriate datatype
df.dtypes
# Out:
# Number       int64
# City        object
# Gender      object
# Age          int64
# Income     float64
# Illness     object
# dtype: object

# %% [markdown]
# ## 4. External Data Source Validation

# %% [markdown]
# Making sure your data matches something outside of the dataset is very important. It allows you to ensure that the measurements are roughly in line with what they should be and it serves as a check on what other things might be wrong in your dataset. External validation can often be as simple as checking your data against a single number, as we will do here.
#
# An example would be suppose that you're working with a dataset on the population of countries during the year 2016. Validating such information with an external reliable resource such as World Bank Data would be important step to providing credibility to your dataset. Have a look at the following link for an example. [Link](https://rstudio-pubs-static.s3.amazonaws.com/182250_19977d0c5c06403fbad1e653850fc7c6.html).

# %% [markdown]
# ### a.Validation

# %% [markdown]
# ## 5. Tidying the Dataset

# %%
# Checking for Outliers
sns.boxplot(x=df['Age'])

# %%
# Checking for Outliers
sns.boxplot(x=df['Income'])

# %%
# Checking for Anomalies
df.boxplot()

# %%
# Identifying the Missing Data
df.isnull().sum()
# Out:
# Number     0
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64

# %%
# Dealing with the Missing Data
#No missing data

# %% [markdown]
# ## 6. Exploratory Analysis

# %%
# Ploting the univariate summaries and recording our observations
df.describe()
# Out:
#               Number            Age         Income
# count  150000.000000  150000.000000  150000.000000
# mean    75000.500000      44.950200   91252.798273
# std     43301.414527      11.572486   24989.500948
# min         1.000000      25.000000    -654.000000
# 25%     37500.750000      35.000000   80867.750000
# 50%     75000.500000      45.000000   93655.000000
# 75%    112500.250000      55.000000  104519.000000
# max    150000.000000      65.000000  177157.000000

# %% [markdown]
# ## 7. Implementing the Solution

# %%
# Implementing the Solution
#How can a US insurance company determine 
#the top 10 cities where its clients have the highest annual income for persons aged 40 and below?
df1 = df[(df['Age'] < 40)]
df2 = df1.drop(columns=['Number','Gender','Illness'])
df3 = df2.groupby(by='City').mean()
df4 = df3.sort_values(by='Income', ascending=0)
df4
# Out:
#                        Age         Income
# City
# Mountain View    32.237948  135013.810068
# San Diego        32.136776  101310.862089
# New York City    32.222919   96959.705119
# Los Angeles      32.158171   95312.372223
# Boston           32.149394   91188.900740
# Austin           32.172985   90267.905447
# Washington D.C.  32.284810   71020.554963
# Dallas           32.201783   45103.665770

# %% [markdown]
# ## 8. Challenging the solution

# %% [markdown]
# > The easy solution is nice because it is, well, easy, but you should never allow those results to hold the day. You should always be thinking of ways to challenge the results, especially if those results comport with your prior expectation.

# %% [markdown]
# ## 9. Follow up questions

# %% [markdown]
# > At this point, we can refine our question or collect new data, all in an iterative process to get at the truth.

# %% [markdown]
# ### a). Did we have the right data?

# %% [markdown]
# # b). Do we need other data to answer our question?

# %% [markdown]
# ### c). Did we have the right question?
